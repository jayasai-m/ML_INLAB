# %% [markdown]
# <a href="https://colab.research.google.com/github/jayasai-m/ML_INLAB/blob/main/ml_lab_postlab_task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# Load Titanic dataset
df = sns.load_dataset("titanic")

# Display original shape
print("Original Shape:", df.shape)

# Fill missing values
df["age"] = df["age"].fillna(df["age"].mean())
df["embarked"] = df["embarked"].fillna(df["embarked"].mode()[0])

# Remove unnecessary column
df = df.drop(columns=["deck"])

# Convert categorical values to numeric
df["sex"] = df["sex"].map({"male": 0, "female": 1})
df["embarked"] = df["embarked"].map({"S": 0, "C": 1, "Q": 2})

# Display final shape
print("Processed Shape:", df.shape)

# Check remaining missing values
print("\nRemaining Missing Values:")
print(df[["age", "sex", "embarked"]].isnull().sum())

# Display processed data
print("\nProcessed Dataset:")
print(df[["survived", "pclass", "sex", "age", "fare", "embarked"]].head())
# Out:
# Original Shape: (891, 15)
# Processed Shape: (891, 14)
#
# Remaining Missing Values:
# age         0
# sex         0
# embarked    0
# dtype: int64
#
# Processed Dataset:
#    survived  pclass  sex   age     fare  embarked
# 0         0       3    0  22.0   7.2500         0
# 1         1       1    1  38.0  71.2833         1
# 2         1       3    1  26.0   7.9250         0
# 3         1       1    1  35.0  53.1000         0
# 4         0       3    0  35.0   8.0500         0
